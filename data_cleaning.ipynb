# %% [markdown]
# ##  STEP1:IMPORT LIBRARIES

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## STEP2: LOAD THE DATASET

# %%
df = pd.read_csv("../data/Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## STEP3:DATASET OVERVIEW

# %%
print(df.shape)
# Out:
# (200, 5)

# %% [markdown]
# Column Informaton

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None

# %% [markdown]
# ## STEP4: STATISTICAL SUMMARY

# %%
print(df.describe())
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ## STEP5: CHECK MISSING VALUES

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## STEP6: CHECK DUPLICATE RECORDS

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## STEP7: REMOVE DUPLICATES

# %%
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## STEP8: HANDLEING MISSING VALUES

# %%
numeric_cols = df.select_dtypes(
    include=['int64','float64']
).columns

for col in numeric_cols:
    df[col] = df[col].fillna(df[col].mean())
    df.head()

# %% [markdown]
# Categorical Columns

# %%
categorical_cols = df.select_dtypes(
    include=['object']
).columns

for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])
    df.head()

# %%
df[categorical_cols].isnull().sum()
# Out:
# Gender    0
# dtype: int64

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# ## STEP9: CHECK DATA CONSISTENCY

# %%
print(df[df['Age'] < 0])
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Annual Income (k$), Spending Score (1-100)]
# Index: []

# %%
print(df[df['Age'] > 100])
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Annual Income (k$), Spending Score (1-100)]
# Index: []

# %% [markdown]
# ## STEP10 : OUTLIER DETECTION

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

print(df[(df['Age'] < lower) |
         (df['Age'] > upper)])
# Out:
# Empty DataFrame
# Columns: [CustomerID, Gender, Age, Annual Income (k$), Spending Score (1-100)]
# Index: []

# %% [markdown]
# ## STEP11: FEATURE ENGINEERING

# %%
df['Age_Group'] = pd.cut(
    df['Age'],
    bins=[0,18,35,60,100],
    labels=[
        'Teen',
        'Young Adult',
        'Adult',
        'Senior'
    ]
)

# %% [markdown]
# ## STEP12:VERIFYING CLEANED DATA

# %%
print(df.info())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
#  5   Age_Group               200 non-null    category
# dtypes: category(1), int64(4), object(1)
# memory usage: 8.3+ KB
# None
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# Age_Group                 0
# dtype: int64
